# %%
# load_predict.py

import numpy as np
import joblib
from tensorflow.keras.models import load_model
import warnings
warnings.filterwarnings('ignore')
# Load the trained model
model = load_model('ann_model.h5')

# Load the scaler
scaler = joblib.load('input_scaler.pkl')

# %%
# load_predict.py

import numpy as np
import joblib
from tensorflow.keras.models import load_model
import warnings
warnings.filterwarnings('ignore')
# Load the trained model
model = load_model('ann_model.h5')

# Load the scaler
scaler = joblib.load('input_scaler.pkl')
new_input = np.array([[40,1,38,0,7,4,2,4,1,0,0,8,1,5,1,4,130,200,100]])  # shape: (1, n_features)

# Scale the input
new_input_scaled = scaler.transform(new_input)

# Make prediction
prediction = model.predict(new_input_scaled)
predicted_class = np.argmax(prediction, axis=1)[0]
cls=['Low','Medium','High']
print(f"Predicted Class: {cls[predicted_class]} \n index {predicted_class}")
# Out:
# Predicted Class: Low
#  index 0

# %%
# load_predict.py

import numpy as np
import joblib
from tensorflow.keras.models import load_model
import warnings
warnings.filterwarnings('ignore')
# Load the trained model
model = load_model('ann_model.h5')

# Load the scaler
scaler = joblib.load('input_scaler.pkl')
new_input = np.array([[30,1,150,2,7,4,2,4,1,0,0,8,1,5,1,1,120,180,90]])  # shape: (1, n_features)

# Scale the input
new_input_scaled = scaler.transform(new_input)

# Make prediction
prediction = model.predict(new_input_scaled)
predicted_class = np.argmax(prediction, axis=1)[0]
cls=['Low','Medium','High']
print(f"Predicted Class: {cls[predicted_class]} \n index {predicted_class}")
# Out:
# Predicted Class: Medium
#  index 1

# %%
# load_predict.py

import numpy as np
import joblib
from tensorflow.keras.models import load_model
import warnings
warnings.filterwarnings('ignore')
# Load the trained model
model = load_model('ann_model.h5')

# Load the scaler
scaler = joblib.load('input_scaler.pkl')

# Sample new input (replace with your frontend-provided values)
# Example: new_input = [feature1, feature2, ..., featureN]
new_input = np.array([[32,0,69,2,7,4,1,6,3,0,0,9,0.5,2,0,0,120,190,85]])  # shape: (1, n_features)

# Scale the input
new_input_scaled = scaler.transform(new_input)

# Make prediction
prediction = model.predict(new_input_scaled)
predicted_class = np.argmax(prediction, axis=1)[0]
cls=['Low','Medium','High']
print(f"Predicted Class: {cls[predicted_class]} \n index {predicted_class}")
# Out:
# Predicted Class: High
#  index 2

# %%
import pandas
data=pandas.read_csv("processed.csv")

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Occupation', 'Marital_Status', 'Sleep_Duration',
#        'Sleep_Quality', 'Physical_Activity', 'Screen_Time', 'Caffeine_Intake',
#        'Alcohol_Intake', 'Smoking_Habit', 'Work_Hours', 'Travel_Time',
#        'Social_Interactions', 'Meditation_Practice', 'Exercise_Type',
#        'Blood_Pressure', 'Cholesterol_Level', 'Blood_Sugar_Level',
#        'Stress_Detection'],
#       dtype='object')

# %%
len(data.columns)
# Out:
# 20
